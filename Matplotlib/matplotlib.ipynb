# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3]
y=[11,22,33]
plt.plot(x,y);       #Staless way of plotting

# %%
# Use object oriented interfance rather than pyplot interface

# %% [markdown]
# # 1st method

# %%
fig = plt.figure()   # creates figures
ax = fig.add_subplot()  #adds some axes

# %% [markdown]
# # 2nd method

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y);

# %% [markdown]
# # 3rd method : most used

# %%
fig, ax = plt.subplots()   #Object oriented API
ax.plot(x,y);

# %% [markdown]
# # Matplotlib workflow example

# %%
# 1. prepare the data
x=[1,2,3,4]
y=[10,10,30,40]

# 2. setup plot
fig,ax = plt.subplots(figsize=(10,5))  #width,height

# 3. plot data
ax.plot(x,y)
ax.set(title="Simple plot",
      xlabel="X-axis",
      ylabel="Y-axis")
plt.show()

# %% [markdown]
# # Making plots using numpy arrays
#     Lineplot
#     Scatterplot
#     Barplot
#     Histogram
#     Subplot

# %%
x=np.linspace(0,5,50)
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %% [markdown]
# # Lineplot

# %%
#Plot the data:
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %% [markdown]
# # Scatter Plot

# %%
# Scatter plot 1
fig,ax=plt.subplots()
ax.scatter(x,x**2)

# %%
# Scatter plot 2
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %%
# Scatter plot 3
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %% [markdown]
# # Bar plot : default vertical graph

# %%
# make a dictionary and plot it
prices={"Book":10,
        "Pen":5,
        "Copy":7
       }
fig,ax=plt.subplots(figsize=(10,5))
ax.bar(prices.keys(),prices.values())
ax.set(title="Price Plot",
      xlabel="Materials",
      ylabel="Price");

# %%
# Horizontal graph
prices={"Book":10,
        "Pen":5,
        "Copy":7
       }
fig,ax=plt.subplots(figsize=(10,5))
ax.barh(list(prices.keys()),list(prices.values()))
ax.set(title="Price Plot",
      xlabel="Materials",
      ylabel="Price");

# %% [markdown]
# # Histogram

# %%
# Random array
x=np.random.randn(10000)
fig,ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# # Subplots 1:

# %%
fig, ((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                                        ncols=2,
                                        figsize=(10,10))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(prices.keys(),prices.values())
ax4.hist(np.random.random(5));

# %% [markdown]
# # Subplots 2:

# %%
fig, ax = plt.subplots(figsize=(10,5),
                      nrows=2,
                      ncols=2)
ax[0,0].plot(x,x/2);       #specifies the location i.e oth row oth column
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(prices.keys(),prices.values())
ax[1,1].hist(np.random.random(5));

# %% [markdown]
# # Plotting from pandas dataFrames

# %%
car_sales=pd.read_csv("car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts=pd.Series(np.random.randn(1000),
            index=pd.date_range("1/1/2024",
            periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Plot same for car_sales

# %%
#convert price to numeric:
car_sales["Price"]=car_sales["Price"].str.replace("[\$\,]",'')
car_sales
# Out:
# /var/folders/tg/lmwvqpj52v571r3rpp5rs_900000gn/T/ipykernel_72501/1827712352.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace("[\$\,]",'')
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   4000.00
# 1   Honda    Red          87899      4   5000.00
# 2  Toyota   Blue          32549      3   7000.00
# 3     BMW  Black          11179      5  22000.00
# 4  Nissan  White         213095      4   3500.00
# 5  Toyota  Green          99213      4   4500.00
# 6   Honda   Blue          45698      4   7500.00
# 7   Honda   Blue          54738      4   7000.00
# 8  Toyota  White          60000      4   6250.00
# 9  Nissan  White          31600      4   9700.00

# %%
# add sales column according to the date
car_sales["Sale Date"]=pd.date_range("1/1/2024",periods=10)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sale Date
# 0  Toyota  White         150043      4   4000.00 2024-01-01
# 1   Honda    Red          87899      4   5000.00 2024-01-02
# 2  Toyota   Blue          32549      3   7000.00 2024-01-03
# 3     BMW  Black          11179      5  22000.00 2024-01-04
# 4  Nissan  White         213095      4   3500.00 2024-01-05
# 5  Toyota  Green          99213      4   4500.00 2024-01-06
# 6   Honda   Blue          45698      4   7500.00 2024-01-07
# 7   Honda   Blue          54738      4   7000.00 2024-01-08
# 8  Toyota  White          60000      4   6250.00 2024-01-09
# 9  Nissan  White          31600      4   9700.00 2024-01-10

# %%
# Add total sale price using cumsum:
car_sales["Total sale"]=car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sale Date  \
# 0  Toyota  White         150043      4   4000.00 2024-01-01
# 1   Honda    Red          87899      4   5000.00 2024-01-02
# 2  Toyota   Blue          32549      3   7000.00 2024-01-03
# 3     BMW  Black          11179      5  22000.00 2024-01-04
# 4  Nissan  White         213095      4   3500.00 2024-01-05
# 5  Toyota  Green          99213      4   4500.00 2024-01-06
# 6   Honda   Blue          45698      4   7500.00 2024-01-07
# 7   Honda   Blue          54738      4   7000.00 2024-01-08
# 8  Toyota  White          60000      4   6250.00 2024-01-09
# 9  Nissan  White          31600      4   9700.00 2024-01-10
#
#                                           Total sale
# 0                                            4000.00
# 1                                     4000.005000.00
# 2                              4000.005000.007000.00
# 3                      4000.005000.007000.0022000.00
# ...

# %% [markdown]
# # Above it just concatenates the prices , because price is still str type

# %%
#Resolve it:
car_sales["Total sales"]=car_sales["Price"].astype(float).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sale Date  \
# 0  Toyota  White         150043      4   4000.00 2024-01-01
# 1   Honda    Red          87899      4   5000.00 2024-01-02
# 2  Toyota   Blue          32549      3   7000.00 2024-01-03
# 3     BMW  Black          11179      5  22000.00 2024-01-04
# 4  Nissan  White         213095      4   3500.00 2024-01-05
# 5  Toyota  Green          99213      4   4500.00 2024-01-06
# 6   Honda   Blue          45698      4   7500.00 2024-01-07
# 7   Honda   Blue          54738      4   7000.00 2024-01-08
# 8  Toyota  White          60000      4   6250.00 2024-01-09
# 9  Nissan  White          31600      4   9700.00 2024-01-10
#
#                                           Total sale  Total sales
# 0                                            4000.00       4000.0
# 1                                     4000.005000.00       9000.0
# 2                              4000.005000.007000.00      16000.0
# ...

# %%
#Dropping off the prev total sale column
car_sales.drop(columns=["Total sale"],inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000.00 2024-01-01       4000.0
# 1   Honda    Red          87899      4   5000.00 2024-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.00 2024-01-03      16000.0
# 3     BMW  Black          11179      5  22000.00 2024-01-04      38000.0
# 4  Nissan  White         213095      4   3500.00 2024-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.00 2024-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.00 2024-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.00 2024-01-08      60500.0
# 8  Toyota  White          60000      4   6250.00 2024-01-09      66750.0
# 9  Nissan  White          31600      4   9700.00 2024-01-10      76450.0

# %%
car_sales.plot(x="Sale Date",
              y="Total sales",);

# %%
fig,ax=plt.subplots()
ax.scatter(car_sales["Odometer (KM)"],car_sales["Price"])
ax.set(xlabel="Odometer (KM)",
      ylabel="Price");

# Instead do this for same plot::
# car_sales.plot(x="Odometer (KM)",
#               y="Price",
#               kind="scatter");

# %%
car_sales["Price"]=car_sales["Price"].astype(float)

# %%
 car_sales.plot(x="Odometer (KM)",
              y="Price",
              kind="bar"); #can do for any parameters

# %%
car_sales.plot.bar();

# %%
car_sales["Price"].plot.hist(bins=10)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# # Lets try on heart disease dataset:

# %%
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(bins=50)  #higher bins shows the outliers in the dataset
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#Lets plot entire columns in histogram: not a good practice
heart_disease.plot.hist(figsize=(10,20),subplots=True);   # this practice is not ideal for all attributes

# %% [markdown]
# # Which method to use?(Pyplot vs matplotlib OO method)
#  Use pyplot plot for quick visualization but for better understanding use OO method

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Retrive the data of the people over age 50 
over50=heart_disease[heart_disease["age"]>50]
over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %% [markdown]
# # Pyplot method:

# %%
#Scatter plot for the age and the cholestrol with target color
over50.plot.scatter(x="age",
            y="chol",
            c="target");

# %% [markdown]
# # OO method: scratch (Recommended)

# %%
#OO method from scratch:
fig, ax= plt.subplots(figsize=(10,6))
scatter=ax.scatter(x=over50["age"],
           y=over50["chol"],
          c=over50["target"])

# make a labels:
ax.set(title="Heart disease and cholestrol level",
      xlabel="AGE",
      ylabel="CHOLESTROL")
# like the previous one there is a legend on the right side, lets put that too
ax.legend(*scatter.legend_elements(),title="target")
ax.set_xlim(50,75);  #Set the x-axis view limits.ft

# %% [markdown]
# # OO method (Alternative)

# %%
fig, ax= plt.subplots(figsize=(10,6))
over50.plot(kind='scatter',
        x='age',
        y='chol',
        c='target',
        ax=ax)
ax.set_xlim(50,75);  #Set the x-axis view limits.

# %% [markdown]
# # Adding a horizontal inside of the plot

# %%
fig, ax= plt.subplots(figsize=(10,6))
scatter=ax.scatter(x=over50["age"],
           y=over50["chol"],
          c=over50["target"])

# make a labels:
ax.set(title="Heart disease and cholestrol level",
      xlabel="AGE",
      ylabel="CHOLESTROL")
# like the previous one there is a legend on the left side, lets put that too
ax.legend(*scatter.legend_elements(),title="target")
ax.set_xlim(50,75) #Set the x-axis view limits.

# a horizontal line:
ax.axhline(250,xmin=0,xmax=1,linestyle="--"); 
# xmin to xmax: 0-1 i.e origin to max x_axis(can be made according to the need)

# %% [markdown]
# # Subplot of chol , thalach vs age:

# %%
#creating axes:
fig, (ax0,ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,10),
                           #sharex=True 
                           )               #Note: here x axis is shared in both subplots: 
# adding data to ax0:
scatter=ax0.scatter(x=over50["age"],
                   y=over50["chol"],
                   c=over50['target'])
# customize:
ax0.set(title="Heart disease & Cholestrol level",
       xlabel="Age",
       ylabel="Cholestrol",
       )
# adding legend:
ax0.legend(*scatter.legend_elements(),title="target")
# mean line:
ax0.axhline(250,linestyle='--')

# adding data to ax1:
scatter1=ax1.scatter(x=over50["age"],
                    y=over50["thalach"],
                    c=over50['target'])

# customize:
ax1.set(title="Heart disease & Thalach level",
        xlabel="Age",
       ylabel="Thalach")

# adding legend:
ax1.legend(*scatter.legend_elements(),title="target")
# mean line:
ax1.axhline(140,linestyle='--')

fig.suptitle('Heart disease analysis',fontsize=15,fontweight='bold');

# %% [markdown]
# # Styles in matplotlib

# %%
# See different styles :
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000.0 2024-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2024-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2024-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2024-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2024-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2024-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2024-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2024-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2024-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2024-01-10      76450.0

# %%
car_sales["Price"].plot();

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')
# Out:
# /var/folders/tg/lmwvqpj52v571r3rpp5rs_900000gn/T/ipykernel_72501/240305066.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid')
car_sales["Price"].plot();

# %% [markdown]
# # Creating Random datas

# %%
x=np.random.randn(10,5)
x
# Out:
# array([[-2.76545188,  0.05458976,  0.45175339,  1.15372605, -0.75362308],
#        [-2.6255276 , -1.07858065,  0.69967242,  0.13399392, -0.95226512],
#        [-0.37163273,  1.10854137,  0.59746659, -0.5549887 , -0.40026437],
#        [-0.45760163,  1.24317463, -0.23368851, -1.44746591, -0.94930506],
#        [-0.74646919,  0.22264258,  0.35413124, -0.7905793 , -0.2823295 ],
#        [ 0.10494333,  1.47885462, -0.47718165, -0.67083673, -0.55299285],
#        [-1.5104874 , -0.45092844,  0.1490472 , -1.00938115, -1.84953263],
#        [-0.77487408,  0.36526089,  0.06184759, -2.22388168,  0.44064242],
#        [-0.33198963,  0.22460485, -0.74424773,  0.20031994,  0.67015529],
#        [ 0.83603895, -1.87985765,  0.3172499 ,  0.26368105,  0.18850286]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d','e'])
df
# Out:
#           a         b         c         d         e
# 0 -2.765452  0.054590  0.451753  1.153726 -0.753623
# 1 -2.625528 -1.078581  0.699672  0.133994 -0.952265
# 2 -0.371633  1.108541  0.597467 -0.554989 -0.400264
# 3 -0.457602  1.243175 -0.233689 -1.447466 -0.949305
# 4 -0.746469  0.222643  0.354131 -0.790579 -0.282330
# 5  0.104943  1.478855 -0.477182 -0.670837 -0.552993
# 6 -1.510487 -0.450928  0.149047 -1.009381 -1.849533
# 7 -0.774874  0.365261  0.061848 -2.223882  0.440642
# 8 -0.331990  0.224605 -0.744248  0.200320  0.670155
# 9  0.836039 -1.879858  0.317250  0.263681  0.188503

# %%
ax=df.plot.bar()

# %%
# Customizing using set
ax=df.plot(kind="bar")
# Adding the title and the labels
ax.set(title="Random numbers",
      xlabel="X axis",
      ylabel="Y axis")
# making legend visible
ax.legend().set_visible(True)

# %%
over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# Vizualizing 
fig,ax=plt.subplots()
#Scatter plot
scatter=ax.scatter(x=over50["age"],y=over50["chol"],
                   c=over50["target"],
                   cmap="plasma"
                  )

# Labling
ax.set(title="Age vs Cholestrol",
      xlabel="Age",
      ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(),title="target")
#adding horizontal line
ax.axhline(390,linestyle="--",color="g")
#Setting limits to x axis view
ax.set_xlim(50,75)
# Out:
# (50.0, 75.0)

# %% [markdown]
# # Subplots of age vs thalach & age vs trestbps

# %%
over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
plt.style.use("default")
# creating axes
fig, (ax1,ax2)=plt.subplots(nrows=2,ncols=1,figsize=(10,10))
#Scatter plot 1
scatter1=ax1.scatter(x=over50["age"],
           y=over50["thalach"],
           c=over50["target"],
           cmap="winter")
#labling plot
ax1.set(title="Age vs Thalach",
       xlabel="Age",
       ylabel="Thalach")
# visible legend
ax1.legend(*scatter1.legend_elements(),title="target")

#scatter plot  2
scatter2=ax2.scatter(x=over50["age"],
           y=over50["trestbps"],
           c=over50["target"],
           cmap="summer")
#Horizontal line
ax1.axhline(150)

#limiting x & y axis view
ax1.set_xlim(50,75)
ax1.set_ylim(50,200)

#labling plot
ax2.set(title="Age vs trestbps",
       xlabel="Age",
       ylabel="trestbps")
# visible legend
ax2.legend(*scatter2.legend_elements(),title="target")
ax2.set_xlim(50,75)
ax2.set_ylim(50,200)

fig.suptitle("Heart Disease",fontweight="bold");
